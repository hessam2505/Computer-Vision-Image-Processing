# %%
import cv2

import matplotlib.pyplot as plt

# %%
def imshowfunc(title = "" , image = None , size = 10) :
    h , w = image.shape[0] , image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
image = cv2.imread('landscape.jpeg')

# %%
imshowfunc('image' , image = image , size= 10)

# %%
graysc = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
imshowfunc('Gray Scale' , image = graysc , size = 10)

# %%
image.shape
# Out:
# (1280, 960, 3)

# %%
graysc.shape
#it has one depth
# Out:
# (1280, 960)

# %%
cv2.imwrite('Grayscale_landscape.jpg' , graysc)
# Out:
# True
