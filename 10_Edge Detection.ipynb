# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def imshowfunc(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
image = cv2.imread('number.png',0)
imshowfunc("Original", image)

# %%
# Dilation – Adds pixels to the boundaries of objects in an image
# Erosion – Removes pixels at the boundaries of objects in an image
# Opening - Erosion followed by dilation
# Closing - Dilation followed by erosion

# %%
imshowfunc('Original' , image)

kernel = np.ones((5,5) , np.uint8)

erosion = cv2.erode(image , kernel , iterations= 1)
imshowfunc('Erosion' , erosion)

dilation = cv2.dilate(image,kernel , iterations=1)
imshowfunc('Dilation' , dilation)

opening = cv2.morphologyEx(image,cv2.MORPH_OPEN , kernel)
imshowfunc('Opening' , opening)

celosing = cv2.morphologyEx(image , cv2.MORPH_CLOSE , kernel)
imshowfunc('Closing' , celosing)

# %%
canny = cv2.Canny(image, 50, 120)
imshowfunc('Canny 1', canny)

canny = cv2.Canny(image, 10, 200)
imshowfunc('Canny Wide', canny)

canny = cv2.Canny(image, 200, 240)
imshowfunc('Canny Narrow', canny)

canny = cv2.Canny(image, 60, 110)
imshowfunc('Canny 4', canny)

# %%
image = cv2.imread('mazandaran.jpg')
imshowfunc("Original", image)

# %%
canny = cv2.Canny(image, 50, 120)
imshowfunc('Canny 1', canny)

canny = cv2.Canny(image, 10, 200)
imshowfunc('Canny Wide', canny)

canny = cv2.Canny(image, 200, 240)
imshowfunc('Canny Narrow', canny)

canny = cv2.Canny(image, 60, 110)
imshowfunc('Canny 4', canny)

canny = cv2.Canny(image,350,390)
imshowfunc('Canny 5', canny)

# %%
def autoCanny(image):
    
    blurred_img = cv2.blur(image, ksize=(5,5))
    med_val = np.median(image) 
    lower = int(max(0, 0.66 * med_val))
    upper = int(min(255, 1.33 * med_val))
    edges = cv2.Canny(image=image, threshold1=lower, threshold2=upper)
    return edges

auto_canny = autoCanny(image)
imshowfunc("auto canny", auto_canny)
